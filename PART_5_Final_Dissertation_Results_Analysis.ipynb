# %% [markdown]
# # PART 5 — Final Dissertation Results and Figure Generation

# %% [markdown]
# # PART 5 — Final Dissertation Results Analysis
#
#
#
# Outputs:
# - Model comparison tables
# - Metric graphs
# - Kidney vs Tumour comparison
# - HD95 analysis
# - Final qualitative figure preparation

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

PROJECT_PATH = r"C:\Users\USER\Kidney_Segmentation_Project"

RESULT_PATH = os.path.join(PROJECT_PATH,"results")
FIGURE_PATH = os.path.join(PROJECT_PATH,"figures")

os.makedirs(FIGURE_PATH, exist_ok=True)

print("Final analysis environment ready.")

# %%
# Load final model results

# Replace filenames after generating actual outputs

models = pd.DataFrame({
    "Model":[
        "3D U-Net",
        "nnU-Net",
        "Enhanced Attention Transformer U-Net"
    ],
    "Dice":[0,0,0],
    "IoU":[0,0,0],
    "Precision":[0,0,0],
    "Recall":[0,0,0]
})

models

# %%
# Overall performance graph

plt.figure(figsize=(9,5))

x=models["Model"]

plt.bar(x, models["Dice"])

plt.ylabel("Dice Score")
plt.title("Final Model Dice Comparison")
plt.xticks(rotation=20)

plt.savefig(
    os.path.join(
        FIGURE_PATH,
        "Final_Dice_Comparison.png"
    ),
    dpi=600,
    bbox_inches="tight"
)

plt.show()

# %%
# Kidney vs Tumour comparison template

kidney_tumour = pd.DataFrame({
    "Model":["3D U-Net","nnU-Net","Enhanced Model"],
    "Kidney Dice":[0,0,0],
    "Tumour Dice":[0,0,0]
})

kidney_tumour
