# %% [markdown]
# # PART 4 — Advanced Models Implementation and Comparison

# %% [markdown]
# # PART 4 — nnU-Net + Enhanced Attention Transformer U-Net
#
# ## Purpose
# Advanced model implementation and comparison.
#
# This notebook contains:
# - nnU-Net dataset preparation notes
# - Enhanced Attention Transformer U-Net architecture
# - Training configuration
# - Model comparison framework

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

PROJECT_PATH = r"C:\Users\USER\Kidney_Segmentation_Project"

MODEL_PATH = os.path.join(PROJECT_PATH,"models")
RESULT_PATH = os.path.join(PROJECT_PATH,"results")
FIGURE_PATH = os.path.join(PROJECT_PATH,"figures")

os.makedirs(MODEL_PATH, exist_ok=True)
os.makedirs(RESULT_PATH, exist_ok=True)
os.makedirs(FIGURE_PATH, exist_ok=True)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(DEVICE)

# %% [markdown]
# ## nnU-Net Pipeline

# %%
# Placeholder structure for nnU-Net result loading

nnunet_results = {
    "Dice": [],
    "IoU": [],
    "Precision": [],
    "Recall": [],
    "HD95": []
}

print("Loaded nnU-Net predictions and metrics here.")

# %% [markdown]
# ## Enhanced Attention Transformer U-Net
#
# Components:
# - 3D convolution blocks
# - Attention feature selection
# - Transformer-style global feature modelling
# - Decoder reconstruction

# %%
class AttentionBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.attention = nn.Sequential(
            nn.Conv3d(channels, channels, 1),
            nn.Sigmoid()
        )

    def forward(self,x):
        return x*self.attention(x)


class EnhancedAttentionModule(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.att = AttentionBlock(channels)

    def forward(self,x):
        return self.att(x)


print("Enhanced attention components created.")

# %%
# Final comparison template

comparison = pd.DataFrame({
    "Model":["3D U-Net","nnU-Net","Enhanced Attention Transformer U-Net"],
    "Dice":[0,0,0],
    "IoU":[0,0,0],
    "Precision":[0,0,0],
    "Recall":[0,0,0],
    "HD95":[0,0,0]
})

comparison
